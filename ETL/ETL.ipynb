# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
import random

# %% [markdown]
# # Set up

# %% [markdown]
# Set seed value

# %%
SEED = 212

# %% [markdown]
# Set random elements to seeds where possible

# %%
def seed_torch(seed=SEED):
    th.manual_seed(seed)
    random.seed(seed)
    th.cuda.manual_seed(seed)
    th.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    np.random.seed(seed)  # Numpy module.
    random.seed(seed)  # Python random module.
    th.manual_seed(seed)
    th.backends.cudnn.benchmark = True
    th.backends.cudnn.deterministic = True

seed_torch()

# %% [markdown]
# Read in data set

# %%
df = pd.read_csv('../data/freMTPL2freq.csv')

# %% [markdown]
# ## Transformations, corrections, and splitting

# %%
df['VehPower'] = df['VehPower'].astype(object) # categorical ordinal
df['ClaimNb'].values[df['ClaimNb']>4] = 4 # corrected for unreasonable observations (see M.V. Wuthrich)
df['VehAge'].values[df['VehAge']>20] = 20 # capped for NN training (see M.V. Wuthrich)
df['DrivAge'].values[df['DrivAge']>90] = 90 # capped for NN training (see M.V. Wuthrich)
df['BonusMalus'].values[df['BonusMalus']>150] = 150 # capped for NN training (see M.V. Wuthrich)
df['Density']=np.log(df['Density']) # logged for NN training     (see M.V. Wuthrich)
df['Exposure'].values[df['Exposure']>1] = 1 # corrected for unreasonable observations (see M.V. Wuthrich)
df_new = df.drop(['IDpol'], axis=1) # variable not used

# %% [markdown]
# Check for missing values

# %%
missing = df_new.isnull().sum()/df_new.shape[0]*100
missing
# Out:
# ClaimNb       0.0
# Exposure      0.0
# Area          0.0
# VehPower      0.0
# VehAge        0.0
# DrivAge       0.0
# BonusMalus    0.0
# VehBrand      0.0
# VehGas        0.0
# Density       0.0
# Region        0.0
# dtype: float64

# %% [markdown]
# Encode the data as per Wuthrich

# %%
df_new_encoded = pd.get_dummies(df_new, columns=['VehBrand', 'Region'], drop_first=True)

# %% [markdown]
# Label encode oredered catergorical variables as per Wutrich

# %%
cleanup_nums = {"Area":     {"A": 1, "B": 2, "C": 3, "D": 4, "E":5, "F": 6},
                "VehGas":   {"Regular": 1, "Diesel": 2}
                }

# %% [markdown]
# Apply label encoding - NOT ONE-HOT/DUMMY

# %%
df_new_encoded = df_new_encoded.replace(cleanup_nums)

# %% [markdown]
# Split data into X and y dataframes

# %%
X = df_new_encoded.iloc[:, 1:]
y = df_new_encoded.iloc[:, 0]

# %% [markdown]
# Split data into Train(Val) and final Test test

# %%
X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, test_size=0.2,  random_state=SEED)

# %% [markdown]
# Use Train(Val) to perform MinMax scaling. **Importantly** this scaler is dervied ONLY using Train(Val) data to avoid data leakage i.e. Test data should only be transformed using Training scalers

# %%
scaler = MinMaxScaler()
scaler.fit(X_trainval)
# Out:
# MinMaxScaler()

# %%
X_trainval[['Area', 'VehPower', 'VehAge','DrivAge','BonusMalus','Density']] = scaler.fit_transform(X_trainval[['Area', 'VehPower', 'VehAge','DrivAge','BonusMalus','Density']])
X_test[['Area', 'VehPower', 'VehAge','DrivAge','BonusMalus','Density']] = scaler.fit_transform(X_test[['Area', 'VehPower', 'VehAge','DrivAge','BonusMalus','Density']])

# %% [markdown]
# Check transformations

# %%
no_obj_cols = [var for var in X_trainval.columns if X_trainval[var].dtype!='object']
X_trainval[no_obj_cols].describe().T
# Out:
#                  count      mean       std       min       25%       50%  \
# Exposure      542410.0  0.528417  0.364092  0.002732  0.170000  0.490000
# Area          542410.0  0.457962  0.276476  0.000000  0.200000  0.400000
# VehPower      542410.0  0.223344  0.186676  0.000000  0.090909  0.181818
# VehAge        542410.0  0.348710  0.269851  0.000000  0.100000  0.300000
# DrivAge       542410.0  0.381704  0.196197  0.000000  0.222222  0.361111
# BonusMalus    542410.0  0.097645  0.156113  0.000000  0.000000  0.000000
# VehGas        542410.0  1.490207  0.499905  1.000000  1.000000  1.000000
# Density       542410.0  0.586210  0.183286  0.000000  0.443157  0.585461
# VehBrand_B10  542410.0  0.026281  0.159969  0.000000  0.000000  0.000000
# VehBrand_B11  542410.0  0.020020  0.140068  0.000000  0.000000  0.000000
# VehBrand_B12  542410.0  0.244562  0.429828  0.000000  0.000000  0.000000
# VehBrand_B13  542410.0  0.017830  0.132332  0.000000  0.000000  0.000000
# VehBrand_B14  542410.0  0.005901  0.076594  0.000000  0.000000  0.000000
# VehBrand_B2   542410.0  0.235646  0.424403  0.000000  0.000000  0.000000
# VehBrand_B3   542410.0  0.078826  0.269467  0.000000  0.000000  0.000000
# VehBrand_B4   542410.0  0.036979  0.188711  0.000000  0.000000  0.000000
# VehBrand_B5   542410.0  0.051019  0.220036  0.000000  0.000000  0.000000
# VehBrand_B6   542410.0  0.042230  0.201114  0.000000  0.000000  0.000000
# Region_R21    542410.0  0.004465  0.066673  0.000000  0.000000  0.000000
# Region_R22    542410.0  0.011915  0.108505  0.000000  0.000000  0.000000
# Region_R23    542410.0  0.012876  0.112739  0.000000  0.000000  0.000000
# Region_R24    542410.0  0.237177  0.425352  0.000000  0.000000  0.000000
# Region_R25    542410.0  0.015962  0.125329  0.000000  0.000000  0.000000
# Region_R26    542410.0  0.015400  0.123137  0.000000  0.000000  0.000000
# Region_R31    542410.0  0.040351  0.196782  0.000000  0.000000  0.000000
# Region_R41    542410.0  0.019258  0.137432  0.000000  0.000000  0.000000
# Region_R42    542410.0  0.003261  0.057015  0.000000  0.000000  0.000000
# Region_R43    542410.0  0.001986  0.044516  0.000000  0.000000  0.000000
# Region_R52    542410.0  0.057250  0.232320  0.000000  0.000000  0.000000
# Region_R53    542410.0  0.062126  0.241385  0.000000  0.000000  0.000000
# Region_R54    542410.0  0.028029  0.165055  0.000000  0.000000  0.000000
# Region_R72    542410.0  0.046067  0.209630  0.000000  0.000000  0.000000
# Region_R73    542410.0  0.025200  0.156734  0.000000  0.000000  0.000000
# Region_R74    542410.0  0.006753  0.081900  0.000000  0.000000  0.000000
# Region_R82    542410.0  0.124924  0.330633  0.000000  0.000000  0.000000
# Region_R83    542410.0  0.007730  0.087582  0.000000  0.000000  0.000000
# Region_R91    542410.0  0.052706  0.223445  0.000000  0.000000  0.000000
# Region_R93    542410.0  0.116950  0.321361  0.000000  0.000000  0.000000
# Region_R94    542410.0  0.006714  0.081666  0.000000  0.000000  0.000000
#
#                    75%  max
# Exposure      0.990000  1.0
# Area          0.600000  1.0
# VehPower      0.272727  1.0
# VehAge        0.550000  1.0
# DrivAge       0.513889  1.0
# BonusMalus    0.140000  1.0
# VehGas        2.000000  2.0
# Density       0.725176  1.0
# VehBrand_B10  0.000000  1.0
# VehBrand_B11  0.000000  1.0
# VehBrand_B12  0.000000  1.0
# VehBrand_B13  0.000000  1.0
# VehBrand_B14  0.000000  1.0
# VehBrand_B2   0.000000  1.0
# VehBrand_B3   0.000000  1.0
# VehBrand_B4   0.000000  1.0
# VehBrand_B5   0.000000  1.0
# VehBrand_B6   0.000000  1.0
# Region_R21    0.000000  1.0
# Region_R22    0.000000  1.0
# Region_R23    0.000000  1.0
# Region_R24    0.000000  1.0
# Region_R25    0.000000  1.0
# Region_R26    0.000000  1.0
# Region_R31    0.000000  1.0
# Region_R41    0.000000  1.0
# Region_R42    0.000000  1.0
# Region_R43    0.000000  1.0
# Region_R52    0.000000  1.0
# Region_R53    0.000000  1.0
# Region_R54    0.000000  1.0
# Region_R72    0.000000  1.0
# Region_R73    0.000000  1.0
# Region_R74    0.000000  1.0
# Region_R82    0.000000  1.0
# Region_R83    0.000000  1.0
# Region_R91    0.000000  1.0
# Region_R93    0.000000  1.0
# Region_R94    0.000000  1.0

# %% [markdown]
# Split Train(Val) into Train and Validation

# %%
X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=0.1,  random_state=SEED)

# %% [markdown]
# Join training and validation data back together

# %%
train_array = pd.concat([X_train, y_train], axis=1)
val_array = pd.concat([X_val, y_val], axis=1)

# %% [markdown]
# ## Split data into different workers/companies

# %%
NUM_AGENTS = 2
train_array_split = np.array_split(train_array, NUM_AGENTS)
val_array_split = np.array_split(val_array, NUM_AGENTS)

# %% [markdown]
# Loop through and export

# %%
for i in range(NUM_AGENTS):
    locals()['train_array_splitted_{}'.format(i)] = train_array_split[i]
    locals()['X_train_{}'.format(i)] = locals()['train_array_splitted_{}'.format(i)].iloc[:, 0:39]
    locals()['X_train_{}'.format(i)].to_csv('X_train_'+str(i)+'.csv', index=False)
    locals()['y_train_{}'.format(i)] = locals()['train_array_splitted_{}'.format(i)].iloc[:, 39]
    locals()['y_train_{}'.format(i)].to_csv('y_train_'+str(i)+'.csv', index=False)
    locals()['val_array_splitted_{}'.format(i)] = val_array_split[i]
    locals()['X_val_{}'.format(i)] = locals()['val_array_splitted_{}'.format(i)].iloc[:, 0:39]
    locals()['X_val_{}'.format(i)].to_csv('X_val_'+str(i)+'.csv', index=False)
    locals()['y_val_{}'.format(i)] = locals()['val_array_splitted_{}'.format(i)].iloc[:, 39]
    locals()['y_val_{}'.format(i)].to_csv('y_val_'+str(i)+'.csv', index=False)
